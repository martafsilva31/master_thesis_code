# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
theta_0 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_simplified_process/all/training_samples/alices_gaussian_prior_0_0.4/theta0_train_ratio_ud_wph_mu_smeftsim_lhe_0.npy")
theta_1 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_simplified_process/all/training_samples/alices_gaussian_prior_0_0.4/theta0_train_ratio_ud_wph_mu_smeftsim_lhe_1.npy")
theta_2 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_simplified_process/all/training_samples/alices_gaussian_prior_0_0.4/theta0_train_ratio_ud_wph_mu_smeftsim_lhe_2.npy")
theta_3 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_simplified_process/all/training_samples/alices_gaussian_prior_0_0.4/theta0_train_ratio_ud_wph_mu_smeftsim_lhe_3.npy")
theta_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_simplified_process/all/training_samples/alices_gaussian_prior_0_0.4/theta0_train_ratio_ud_wph_mu_smeftsim_lhe_4.npy")

# %%
median_theta_0 = np.median(theta_0)
median_theta_1 = np.median(theta_1)
median_theta_2 = np.median(theta_2)
median_theta_3 = np.median(theta_3)
median_theta_4 = np.median(theta_4)

mean_theta_0 = np.mean(theta_0)
mean_theta_1 = np.mean(theta_1)
mean_theta_2 = np.mean(theta_2)
mean_theta_3 = np.mean(theta_3)
mean_theta_4 = np.mean(theta_4)

# %%
plt.figure(figsize=(8, 6))

plt.hist(theta_0, bins=50,  label=f'Dataset 1; Med = {median_theta_0:.4f}', histtype='step', density=True)
plt.hist(theta_1, bins=50,  label=f'Dataset 2; Med = {median_theta_1:.4f}', histtype='step', density=True)
plt.hist(theta_2, bins=50,  label=f'Dataset 3; Med = {median_theta_2:.4f}', histtype='step', density=True)
plt.hist(theta_3, bins=50,  label=f'Dataset 4; Med = {median_theta_3:.4f}', histtype='step', density=True)
plt.hist(theta_4, bins=50,  label=f'Dataset 5; Med = {median_theta_4:.4f}', histtype='step', density=True)

plt.xlabel(r'$\theta$')
plt.ylabel('Normalized distribution')
plt.yscale('log')
plt.legend()
plt.savefig("thetas_distribution_gaussian_prior_0.4_BSM_log.pdf")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(theta_0, bins=50, label=f'Dataset 1; Med = {median_theta_0:.4f}', alpha = 0.5,density=True)
plt.xlabel(r'$\theta$')
plt.ylabel('Normalized distribution')
plt.legend()
plt.savefig("theta0_distribution_gaussian_prior_0.4.pdf")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(theta_1, bins=50, label=f'Dataset 2; Med = {median_theta_1:.4f}', color = 'orange',  alpha = 0.5,density=True)
plt.xlabel(r'$\theta$')
plt.ylabel('Normalized distribution')
plt.legend()
plt.savefig("theta1_distribution_gaussian_prior_0.4.pdf")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(theta_2, bins=50, label=f'Dataset 3; Med = {median_theta_2:.4f}', color = 'green',  alpha = 0.5,density=True)
plt.xlabel(r'$\theta$')
plt.ylabel('Normalized distribution')
plt.legend()
plt.savefig("theta2_distribution_gaussian_prior_0.4.pdf")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(theta_3, bins=50, label=f'Dataset 4; Med = {median_theta_3:.4f}', color = 'red',  alpha = 0.5,density=True)
plt.xlabel(r'$\theta$')
plt.ylabel('Normalized distribution')
plt.legend()
plt.savefig("theta3_distribution_gaussian_prior_0.4.pdf")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(theta_4, bins=50, label=f'Dataset 5; Med = {median_theta_4:.4f}', color = 'purple',  alpha = 0.5,density=True)
plt.xlabel(r'$\theta$')
plt.ylabel('Normalized distribution')
plt.legend()
plt.savefig("theta4_distribution_gaussian_prior_0.4.pdf")
plt.show()
