# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
thetas = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.5/theta0_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))
# Create histogram
plt.hist(thetas, bins=20, edgecolor='black', color  = 'g', density=True, alpha=0.5)

# Add labels and title
plt.xlabel(r'$\theta$')
plt.title('Gaussian (0,0.5)')


# Show the plot
plt.show()

# %%
thetas = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.4/theta0_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))
# Create histogram
plt.hist(thetas, bins=20, edgecolor='black', color  = 'g', density=True, alpha=0.5)

# Add labels and title
plt.xlabel(r'$\theta$')
plt.title('Gaussian (0,0.4)')


# Show the plot
plt.show()

# %%
thetas = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.2/theta0_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))
# Create histogram
plt.hist(thetas, bins=20, edgecolor='black', color  = 'g', density=True, alpha=0.5)

# Add labels and title
plt.xlabel(r'$\theta$')
plt.title('Gaussian (0,0.2)')


# Show the plot
plt.show()

# %%
thetas = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_flat_prior_m1.2_p1.2/theta0_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))
# Create histogram
plt.hist(thetas, bins=20, edgecolor='black', color  = 'g', density=True, alpha=0.5)

# Add labels and title
plt.xlabel(r'$\theta$')
plt.title('Gaussian (0,0.2)')


# Show the plot
plt.show()
