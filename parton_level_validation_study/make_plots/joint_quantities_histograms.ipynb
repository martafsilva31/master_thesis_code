# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Joint score extracted from SALLY - Ricardo's paper

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
t_xz_Ricardo = np.load("/lstore/titan/atlas/rbarrue/HWW_tensor_structure/madminer_WH/CPoddOnly_fullME2/met/training_samples/t_xz_train_score_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_Ricardo.flatten()  # Flatten to handle 2D array

# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(column_data, quantiles_for_range[0])
xmax = np.quantile(column_data, quantiles_for_range[1])

plt.figure(figsize=(10, 7))
# Create histogram
plt.hist(column_data, bins=50, range=(xmin, xmax), edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from SALLY (Ricardo\'s paper)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### No quantiles

# %%
t_xz_Ricardo = np.load("/lstore/titan/atlas/rbarrue/HWW_tensor_structure/madminer_WH/CPoddOnly_fullME2/met/training_samples/t_xz_train_score_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_Ricardo.flatten()  # Flatten to handle 2D array

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from SALLY (Ricardo\'s paper)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# # Joint quantities extracted from ALICES - met; gaussian prior centered at 0 with variance 0.5

# %% [markdown]
# ## Score

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
t_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_met_no_BSM_prior_0_5.flatten()  # Flatten to handle 2D array

# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(column_data, quantiles_for_range[0])
xmax = np.quantile(column_data, quantiles_for_range[1])

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, range=(xmin, xmax), edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (met, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
t_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_met_no_BSM_prior_0_5.flatten()  # Flatten to handle 2D array


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (met, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Likelihood ratio

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
r_xz_ALICES_pl_all_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(r_xz_ALICES_pl_all_no_BSM_prior_0_5, quantiles_for_range[0])
xmax = np.quantile(r_xz_ALICES_pl_all_no_BSM_prior_0_5, quantiles_for_range[1])


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_0_5, bins=50, range=(xmin, xmax), edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (met, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
r_xz_ALICES_pl_all_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_0_5, bins=50, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (met, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
r_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_met_no_BSM_prior_0_5, bins=50, edgecolor='black',color = 'r' , density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (met, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### Range [0,4]

# %%
r_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


bins = np.linspace(0, 4, 50)

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_met_no_BSM_prior_0_5, bins=bins, range=(xmin, xmax), edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (met, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# # Joint quantities extracted from ALICES - met; gaussian prior centered at 0 with variance 0.2

# %% [markdown]
# ## Score

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
t_xz_ALICES_met_no_BSM_prior_0_2 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices_gaussian_prior_0_0.2/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_met_no_BSM_prior_0_2.flatten()  # Flatten to handle 2D array

# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(column_data, quantiles_for_range[0])
xmax = np.quantile(column_data, quantiles_for_range[1])

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, range=(xmin, xmax), edgecolor='black', density=True,alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (met, gaussian prior w/ variance = 0.2)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
t_xz_ALICES_met_no_BSM_prior_0_2 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices_gaussian_prior_0_0.2/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_met_no_BSM_prior_0_2.flatten()  # Flatten to handle 2D array


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, edgecolor='black', density=True,alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (met, gaussian prior w/ variance = 0.2)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Likelihood ratio

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
r_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices_gaussian_prior_0_0.2/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(r_xz_ALICES_met_no_BSM_prior_0_5, quantiles_for_range[0])
xmax = np.quantile(r_xz_ALICES_met_no_BSM_prior_0_5, quantiles_for_range[1])


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_met_no_BSM_prior_0_5, bins=50, range=(xmin, xmax), edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (met, gaussian prior w/ variance = 0.2)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
r_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/output_alices_cpv_wh/CPoddOnly_fullME2/met/training_samples/alices_gaussian_prior_0_0.2/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")



plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_met_no_BSM_prior_0_5, bins=50, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (met, gaussian prior w/ variance = 0.2)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# # Joint quantities extracted from ALICES - parton level, all ; gaussian prior centered at 0 with variance 0.5

# %% [markdown]
# ## Score

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
t_xz_ALICES_pl_all_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.5/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_no_BSM_prior_0_5.flatten()  # Flatten to handle 2D array

# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(column_data, quantiles_for_range[0])
xmax = np.quantile(column_data, quantiles_for_range[1])

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, range=(xmin, xmax), edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl all, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
t_xz_ALICES_pl_all_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.5/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_no_BSM_prior_0_5.flatten()  # Flatten to handle 2D array
plt.figure(figsize=(10, 7))
# Create histogram
plt.hist(column_data, bins=50, edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl all, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Likelihood ratio

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
r_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.5/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(r_xz_ALICES_met_no_BSM_prior_0_5, quantiles_for_range[0])
xmax = np.quantile(r_xz_ALICES_met_no_BSM_prior_0_5, quantiles_for_range[1])


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_met_no_BSM_prior_0_5, bins=50, range=(xmin, xmax), edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
r_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.5/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_met_no_BSM_prior_0_5, bins=50, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### Range [0,4]

# %%
r_xz_ALICES_met_no_BSM_prior_0_5 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.5/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))

bins = np.linspace(0, 4, 50)
# Create histogram
plt.hist(r_xz_ALICES_met_no_BSM_prior_0_5, bins=bins, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.5)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# # Joint quantities extracted from ALICES - parton level, all ; gaussian prior centered at 0 with variance 0.2

# %% [markdown]
# ## Score

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
t_xz_ALICES_pl_all_no_BSM_prior_0_2 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.2/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_no_BSM_prior_0_2.flatten()  # Flatten to handle 2D array

# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(column_data, quantiles_for_range[0])
xmax = np.quantile(column_data, quantiles_for_range[1])

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, range=(xmin, xmax), edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl all, gaussian prior w/ variance = 0.2)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
t_xz_ALICES_pl_all_no_BSM_prior_0_2 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.2/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_no_BSM_prior_0_2.flatten()  # Flatten to handle 2D array
plt.figure(figsize=(10, 7))
# Create histogram
plt.hist(column_data, bins=50, edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl all, gaussian prior w/ variance = 0.2)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Likelihood ratio

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
r_xz_ALICES_pl_all_no_BSM_prior_0_2 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.2/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(r_xz_ALICES_pl_all_no_BSM_prior_0_2, quantiles_for_range[0])
xmax = np.quantile(r_xz_ALICES_pl_all_no_BSM_prior_0_2, quantiles_for_range[1])


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_0_2, bins=50, range=(xmin, xmax), edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.2)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
r_xz_ALICES_pl_all_no_BSM_prior_0_2 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.2/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_0_2, bins=50, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.2)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# # Joint quantities extracted from ALICES - parton level, all ; gaussian prior centered at 0 with variance 0.4

# %% [markdown]
# ## Score

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
t_xz_ALICES_pl_all_no_BSM_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.4/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_no_BSM_prior_0_4.flatten()  # Flatten to handle 2D array

# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(column_data, quantiles_for_range[0])
xmax = np.quantile(column_data, quantiles_for_range[1])

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, range=(xmin, xmax), edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl all, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
t_xz_ALICES_pl_all_no_BSM_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.4/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_no_BSM_prior_0_4.flatten()  # Flatten to handle 2D array


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl all, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Likelihood ratio

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
r_xz_ALICES_pl_all_no_BSM_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.4/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(r_xz_ALICES_pl_all_no_BSM_prior_0_4, quantiles_for_range[0])
xmax = np.quantile(r_xz_ALICES_pl_all_no_BSM_prior_0_4, quantiles_for_range[1])


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_0_4, bins=50, range=(xmin, xmax), edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
r_xz_ALICES_pl_all_no_BSM_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.4/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_0_4, bins=50,  edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### Range [0,4]

# %%
r_xz_ALICES_pl_all_no_BSM_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_gaussian_prior_0_0.4/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


plt.figure(figsize=(10, 7))

bins = np.linspace(0, 4, 50)

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_0_4, bins=bins,  edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# # Joint quantities extracted from ALICES - parton level, all ; flat prior [-1.2,1.2]

# %% [markdown]
# ## Score

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
t_xz_ALICES_pl_all_no_BSM_prior_flat = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_flat_prior_m1.2_p1.2/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_no_BSM_prior_flat.flatten()  # Flatten to handle 2D array

# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(column_data, quantiles_for_range[0])
xmax = np.quantile(column_data, quantiles_for_range[1])

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, range=(xmin, xmax), edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl all, flat prior [-1.2,1.2])')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
t_xz_ALICES_pl_all_no_BSM_prior_flat = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_flat_prior_m1.2_p1.2/t_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_no_BSM_prior_flat.flatten()  # Flatten to handle 2D array


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50,  edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl all, flat prior [-1.2,1.2])')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Likelihood ratio

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
r_xz_ALICES_pl_all_no_BSM_prior_flat = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_flat_prior_m1.2_p1.2/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(r_xz_ALICES_pl_all_no_BSM_prior_flat, quantiles_for_range[0])
xmax = np.quantile(r_xz_ALICES_pl_all_no_BSM_prior_flat, quantiles_for_range[1])


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_flat, bins=50, range=(xmin, xmax), edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### No quantile

# %%
r_xz_ALICES_pl_all_no_BSM_prior_flat = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_flat_prior_m1.2_p1.2/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_flat, bins=50, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ### Range [0,4]

# %%
r_xz_ALICES_pl_all_no_BSM_prior_flat = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/all/training_samples/alices_flat_prior_m1.2_p1.2/r_xz_train_ratio_wh_signalOnly_SMonly_noSysts_lhe_0.npy")


plt.figure(figsize=(10, 7))

bins = np.linspace(0, 4, 50)
# Create histogram
plt.hist(r_xz_ALICES_pl_all_no_BSM_prior_flat, bins=bins, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl all, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_SMonly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# # Joint quantities extracted from ALICES - parton level, met with BSM ; gaussian(0,0.4)

# %% [markdown]
# ## Score

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
t_xz_ALICES_pl_all_met_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/met/training_samples/alices_gaussian_prior_0_0.4/t_xz_train_ratio_wh_signalOnly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_met_prior_0_4.flatten()  # Flatten to handle 2D array

# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(column_data, quantiles_for_range[0])
xmax = np.quantile(column_data, quantiles_for_range[1])

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, range=(xmin, xmax), edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl met, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## No quantile

# %%
t_xz_ALICES_pl_all_met_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/met/training_samples/alices_gaussian_prior_0_0.4/t_xz_train_ratio_wh_signalOnly_noSysts_lhe_0.npy")

column_data = t_xz_ALICES_pl_all_met_prior_0_4.flatten()  # Flatten to handle 2D array

plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(column_data, bins=50, edgecolor='black', density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint score extracted from ALICES (pl met, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_noSysts')
#plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# ## Likelihood ratio

# %% [markdown]
# ### Weighted quantile [0.001, 0.999]; nbins = 50

# %%
r_xz_ALICES_pl_met_BSM_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/met/training_samples/alices_gaussian_prior_0_0.4/r_xz_train_ratio_wh_signalOnly_noSysts_lhe_0.npy")


# Define the quantiles for the range
quantiles_for_range = [0.001, 0.999]

# Calculate the quantiles
xmin = np.quantile(r_xz_ALICES_pl_met_BSM_prior_0_4, quantiles_for_range[0])
xmax = np.quantile(r_xz_ALICES_pl_met_BSM_prior_0_4, quantiles_for_range[1])


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_met_BSM_prior_0_4, bins=50, range=(xmin, xmax), edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl met, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %% [markdown]
# ## No quantile

# %%
r_xz_ALICES_pl_met_BSM_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/met/training_samples/alices_gaussian_prior_0_0.4/r_xz_train_ratio_wh_signalOnly_noSysts_lhe_0.npy")


plt.figure(figsize=(10, 7))

# Create histogram
plt.hist(r_xz_ALICES_pl_met_BSM_prior_0_4, bins=50, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl met, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()

# %%
r_xz_ALICES_pl_met_BSM_prior_0_4 = np.load("/lstore/titan/martafsilva/master_thesis/master_thesis_output/parton_level_validation_study_output/met/training_samples/alices_gaussian_prior_0_0.4/r_xz_train_ratio_wh_signalOnly_noSysts_lhe_0.npy")


plt.figure(figsize=(10, 7))

bins = np.linspace(0, 4, 50)
# Create histogram
plt.hist(r_xz_ALICES_pl_met_BSM_prior_0_4, bins=bins, edgecolor='black', color = 'r' ,density=True, alpha=0.7)

# Add labels and title
plt.xlabel('Joint llr extracted from ALICES (pl met, gaussian prior w/ variance = 0.4)')
plt.title('wh_signalOnly_noSysts')
#plt.ylabel('Frequency')
#plt.xlim(-0.1,6)

# Show the plot
plt.show()
